# %% [markdown]
# <a href="https://colab.research.google.com/github/otmaneABBAS/portfolio-3/blob/main/Untitled47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dans ce projet, nous allons analyser l'évolution du Covid 19 dans le monde Source des données: https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide
#
# Voici quelques questions qui peuvent guider notre analyse
#
# Quels sont les pays avec les plus grand nombres de cas ?
# Quels sont les pays avec un taux de mortalité élevé ?
# Comparer la situation par continent?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('https://opendata.ecdc.europa.eu/covid19/casedistribution/csv')

# %%
data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
data.info()

# %%
data.isnull().sum(axis=0)

# %%
#convertir la colonne daterep en datetime
data['dateRep']=pd.to_datetime(data['dateRep'])
# Out:
# <ipython-input-7-7c853f5465ff>:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['dateRep']=pd.to_datetime(data['dateRep'])

# %%
#supprimer toutes les valeurs manquantes
data.dropna(inplace=True)

# %%
#le pays avec les plus grand nombres de cas
data_country=data.groupby('countriesAndTerritories')[['cases','deaths']].sum().sort_values('cases', ascending=False)
data_country.head()
# Out:
#                              cases  deaths
# countriesAndTerritories
# United_States_of_America  16256754  299177
# India                      9884100  143355
# Brazil                     6901952  181402
# Russia                     2653928   46941
# France                     2376852   57911

# %% [markdown]
# # Quels sont les pays avec un taux de mortalité élevé

# %%
data_country['taux_mortalité']=data_country['deaths']/data_country['cases']
y=data_country

# %% [markdown]
# #  Comparer la situation par continent

# %%
data_continent=data.groupby('continentExp')[['cases','deaths']].sum().sort_values('cases', ascending=False)
data_continent
# Out:
#                  cases  deaths
# continentExp
# America       30884895  785370
# Europe        21395058  479706
# Asia          16780431  290097
# Africa         2361775   56134
# Oceania          53298    1151

# %%
#taux de mortalité  par continent dans un ordre décroissant
data_continent['mortality_rate']=data_continent['deaths']/data_continent['cases']
data_continent.sort_values('mortality_rate',ascending=False)
# Out:
#                  cases  deaths  mortality_rate
# continentExp
# America       30884895  785370        0.025429
# Africa         2361775   56134        0.023768
# Europe        21395058  479706        0.022421
# Oceania          53298    1151        0.021596
# Asia          16780431  290097        0.017288

# %%
from google.colab import files

# %%
data_country.to_csv('data_country.csv')

# %%
files.download('data_country.csv')

# %%
data_country = data_country.merge(data[['countriesAndTerritories', 'continentExp']], on='countriesAndTerritories', how='left')
data_country
# Out:
#         countriesAndTerritories     cases  deaths continentExp
# 0      United_States_of_America  16256754  299177      America
# 1      United_States_of_America  16256754  299177      America
# 2      United_States_of_America  16256754  299177      America
# 3      United_States_of_America  16256754  299177      America
# 4      United_States_of_America  16256754  299177      America
# ...                         ...       ...     ...          ...
# 58754                   Vanuatu         0       0      Oceania
# 58755                   Vanuatu         0       0      Oceania
# 58756                   Vanuatu         0       0      Oceania
# 58757                   Vanuatu         0       0      Oceania
# 58758                   Vanuatu         0       0      Oceania
#
# [58759 rows x 4 columns]
